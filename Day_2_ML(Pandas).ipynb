# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandeeshSG/Machine-Learning/blob/main/Day_2_ML(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy are created full of c/c++
#pandas are created full of numpy

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,5,6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[3]
# Out:
# 4

# %%
s=pd.Series([10,11,12,13,14,15])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int64

# %%
s[4]
# Out:
# 14

# %%
s.drop(3,inplace=True) #delete elemeny without changing the indexing & 'inplace=True' will delete a entire element

# %%
s.iloc[3]              #after deleting the element next element will occupy the current index
# Out:
# 14

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4, 5], dtype='int64')

# %%
d=pd.Series([10,11,12,13,14],index=['c','b','a','e','d'])
d
d.drop('e',inplace=True)

# %%
f=[['Arun',10,'20-10-2020'],['Bob',None,None],['Chandru',None,'23-02-2023']]
f
# Out:
# [['Arun', 10, '20-10-2020'],
#  ['Bob', None, None],
#  ['Chandru', None, '23-02-2023']]

# %%
ff=pd.DataFrame(f)    #Change the list to a table format
ff
# Out:
#          0     1           2
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023

# %%
ff[0:1]
# Out:
#       0     1           2
# 0  Arun  10.0  20-10-2020

# %%
ff[0][0]
# Out:
# 'Arun'

# %%
ff[[0,2]]
# Out:
#          0           2
# 0     Arun  20-10-2020
# 1      Bob        None
# 2  Chandru  23-02-2023

# %%
f[1:2]
# Out:
# [['Bob', None, None]]

# %%
ff=pd.DataFrame(f,columns=['Name','Age','DoB'])
ff
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023

# %%
ff['Name']
# Out:
# 0       Arun
# 1        Bob
# 2    Chandru
# Name: Name, dtype: object

# %%
ff['Age']
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
ff['Name'][0]
# Out:
# 'Arun'

# %%
ff.loc[1,'Name']
# Out:
# 'Bob'

# %%
ff.iloc[1,1]
# Out:
# nan

# %%
a=pd.Series([1,2,3,3,2,1])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    2
# 5    1
# dtype: int64

# %%
print(a.plot())
print(a.hist(bins=2))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
a.hist(bins=2)
# Out:
# <Axes: >

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.to_numpy()
# Out:
# array([1, 2, 3, 3, 2, 1])

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
ff
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023

# %%
ff.head(1)
# Out:
#    Name   Age         DoB
# 0  Arun  10.0  20-10-2020

# %%
ff.head()
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023

# %%
ff.tail(-2)
# Out:
#       Name  Age         DoB
# 2  Chandru  NaN  23-02-2023

# %%
ff.tail()
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023

# %%
#None,' ','','-','?','Nil',np.nan (not a number)

# %%
ff.isnull()
# Out:
#     Name    Age    DoB
# 0  False  False  False
# 1  False   True   True
# 2  False   True  False

# %%
ff.isnull().sum()
# Out:
# Name    0
# Age     2
# DoB     1
# dtype: int64

# %%
aa=[['Arun',10,'20-10-2020'],['Bob',None,None],['Chandru',None,'23-02-2023'],['Eve',12,'22-11-2023'],['Ferrai',14,'19-09-2023'],['Gowtham',20,None]]
aa
# Out:
# [['Arun', 10, '20-10-2020'],
#  ['Bob', None, None],
#  ['Chandru', None, '23-02-2023'],
#  ['Eve', 12, '22-11-2023'],
#  ['Ferrai', 14, '19-09-2023'],
#  ['Gowtham', 20, None]]

# %%
aaa=pd.DataFrame(aa,columns=['Name','Age','DoB'])
aaa
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023
# 3      Eve  12.0  22-11-2023
# 4   Ferrai  14.0  19-09-2023
# 5  Gowtham  20.0        None

# %%
aaa.isnull().sum()
# Out:
# Name    0
# Age     2
# DoB     2
# dtype: int64

# %%
aaa.dropna() #drop is used delete the null values ,which will delete a entire row of the null value
# Out:
#      Name   Age         DoB
# 0    Arun  10.0  20-10-2020
# 3     Eve  12.0  22-11-2023
# 4  Ferrai  14.0  19-09-2023

# %%
aaa
# Out:
#       Name   Age         DoB
# 0     Arun  10.0  20-10-2020
# 1      Bob   NaN        None
# 2  Chandru   NaN  23-02-2023
# 3      Eve  12.0  22-11-2023
# 4   Ferrai  14.0  19-09-2023
# 5  Gowtham  20.0        None

# %%
aaa.drop?

# %%
aaa.drop(['Age'],axis=1,inplace=True) #axis=1  ==> column  axis=0  ==>row

# %%
aaa
# Out:
#       Name         DoB
# 0     Arun  20-10-2020
# 1      Bob        None
# 2  Chandru  23-02-2023
# 3      Eve  22-11-2023
# 4   Ferrai  19-09-2023
# 5  Gowtham        None

# %%
aaa.drop([0,2])   #delete rowwise
# Out:
#       Name         DoB
# 1      Bob        None
# 3      Eve  22-11-2023
# 4   Ferrai  19-09-2023
# 5  Gowtham        None

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    2
# 5    1
# dtype: int64

# %%
a>3
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
a[a>3]
# Out:
# Series([], dtype: int64)

# %%
a[a%2!=0]
# Out:
# 0    1
# 2    3
# 3    3
# 5    1
# dtype: int64

# %%
aaa
# Out:
#       Name         DoB
# 0     Arun  20-10-2020
# 1      Bob        None
# 2  Chandru  23-02-2023
# 3      Eve  22-11-2023
# 4   Ferrai  19-09-2023
# 5  Gowtham        None

# %%
aaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   DoB     4 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes

# %%
aaa['Name'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Name, dtype: bool

# %%
print(aaa.shape)
print(aaa.size)
print(aaa.axes)
print(aaa.ndim)
print(aaa.dtypes)
print(aaa.index)
print(aaa.columns)
print(aaa.values)
# Out:
# (6, 2)
# 12
# [RangeIndex(start=0, stop=6, step=1), Index(['Name', 'DoB'], dtype='object')]
# 2
# Name    object
# DoB     object
# dtype: object
# RangeIndex(start=0, stop=6, step=1)
# Index(['Name', 'DoB'], dtype='object')
# [['Arun' '20-10-2020']
#  ['Bob' None]
#  ['Chandru' '23-02-2023']
#  ['Eve' '22-11-2023']
#  ['Ferrai' '19-09-2023']
#  ['Gowtham' None]]

# %%
aaa.DoB
# Out:
# 0    20-10-2020
# 1          None
# 2    23-02-2023
# 3    22-11-2023
# 4    19-09-2023
# 5          None
# Name: DoB, dtype: object

# %%
aaa.loc[0][0]
# Out:
# 'Arun'

# %%
aaa.loc[0,'Name']
# Out:
# 'Arun'

# %%
aaa['DoB'][1]='30-10-2022'

# %%
a=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
a.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(a.item_name)
# Out:
# pandas.core.series.Series

# %%
a.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
a.item_price=a.item_price.str.replace('$','')
a.head(10)
# Out:
# <ipython-input-149-15224f521644>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   a.item_price=a.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
a.item_price=a.item_price.astype(float)
a
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(a.item_price[0])
# Out:
# numpy.float64

# %%
#a.item_price*100

# %%
a.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
a.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
a_drink=a[a.item_price < 1.1]
a
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
a_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
a_drink.item_name.nunique()      #If n is given before the unique the no of unique variables are displayed
# Out:
# 2

# %%
a_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
a[a.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
a[a.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
a[a.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
a.dropna(inplace=True)

# %%
a[a.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
a[a.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
a[a.choice_description.str.contains('Black Beans')].item_name.nunique()
# Out:
# 30

# %%
a[(a.item_name=='Chicken Bowl') & (a.item_price<10)]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
a[(a.item_name=='Chicken Bowl') & (a.item_price<10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
s=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
s.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
s[(s.star_rating>8)&(s.content_rating=='R')]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 281          8.1            The Terminator              R     Action
# 283          8.1             Before Sunset              R      Drama
# 288          8.1               Sling Blade              R      Drama
# 290          8.1                 Prisoners              R      Crime
# 296          8.1            The Wild Bunch              R     Action
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
s[(s.star_rating>8)&(s.content_rating=='R')].sort_values(['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 283          8.1                Before Sunset              R      Drama
# 225          8.1                       3-Iron              R      Crime
# 206          8.1                  Stand by Me              R  Adventure
# 172          8.2                Trainspotting              R      Drama
# 190          8.2                Life of Brian              R     Comedy
# ..           ...                          ...            ...        ...
# 184          8.2          Fanny and Alexander              R      Drama
# 40           8.5               The Green Mile              R      Crime
# 8            8.9             Schindler's List              R  Biography
# 2            9.1       The Godfather: Part II              R      Crime
# 78           8.4  Once Upon a Time in America              R      Crime
#
#      duration                                        actors_list
# ...

# %%
s[s.actors_list.str.contains('Ethan Hawke')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 226          8.1             Boyhood              R  Drama       165
# 238          8.1      Before Sunrise              R  Drama       105
# 283          8.1       Before Sunset              R  Drama        80
# 342          8.0  Dead Poets Society             PG  Drama       128
# 372          8.0     Before Midnight              R  Drama       109
# 499          7.8             Gattaca          PG-13  Drama       106
# 636          7.7        Training Day              R  Crime       122
# 724          7.6         Lord of War              R  Crime       122
# 939          7.4      Predestination              R  Drama        97
#
#                                            actors_list
# 226  [u'Ellar Coltrane', u'Patricia Arquette', u'Et...
# 238  [u'Ethan Hawke', u'Julie Delpy', u'Andrea Ecke...
# 283  [u'Ethan Hawke', u'Julie Delpy', u'Vernon Dobt...
# 342  [u'Robin Williams', u'Robert Sean Leonard', u'...
# ...

# %%
s[s.actors_list.str.contains('Ethan Hawke')].actors_list.nunique()
# Out:
# 9

# %%
s[(s.actors_list.str.contains('Ethan Hawke'))&(s.actors_list.str.contains('Uma Thurman'))].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating    title content_rating  genre  duration  \
# 499          7.8  Gattaca          PG-13  Drama       106
#
#                                        actors_list
# 499  [u'Ethan Hawke', u'Uma Thurman', u'Jude Law']

# %%
#UFO
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
d
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
#d.dropna(inplace=True)
#d

# %%
d.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
d.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
d['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
d['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
q=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
q
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
q.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
q.beer_servings.min()
# Out:
# 0

# %%
q.beer_servings.max()
# Out:
# 376

# %%
q[q.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
q[q.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
q.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
q.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
