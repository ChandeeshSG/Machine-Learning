# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandeeshSG/Machine-Learning/blob/main/CatBoosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
train=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/train.csv")
test=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/test.csv")
train
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
# ...

# %%
train.isnull().sum()
# Out:
# ACTION              0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                  0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
x=train.iloc[:,1:]
x
# Out:
#        RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0         39353   85475         117961         118300         123472
# 1         17183    1540         117961         118343         123125
# 2         36724   14457         118219         118220         117884
# 3         36135    5396         117961         118343         119993
# 4         42680    5905         117929         117930         119569
# ...         ...     ...            ...            ...            ...
# 32764     23497   16971         117961         118300         119993
# 32765     25139  311198          91261         118026         122392
# 32766     34924   28805         117961         118327         120299
# 32767     80574   55643         118256         118257         117945
# 32768     14354   59575         117916         118150         117920
#
#        ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0          117905            117906       290919     117908
# ...

# %%
y=train["ACTION"]
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 32764    1
# 32765    1
# 32766    1
# 32767    1
# 32768    1
# Name: ACTION, Length: 32769, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
cat_features=list(range(0,x.shape[1]))
cat_features
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# !pip install catboost

# %%
from catboost import CatBoostClassifier
params = {'learning_rate': 0.1, 'depth': 6,'l2_leaf_reg': 3, 'iterations': 100}
model = CatBoostClassifier(**params)
model.fit(x_train,y_train,cat_features)
# Out:
# 0:	learn: 0.6187048	total: 14.7ms	remaining: 1.45s
# 1:	learn: 0.5578358	total: 23.5ms	remaining: 1.15s
# 2:	learn: 0.5073925	total: 39ms	remaining: 1.26s
# 3:	learn: 0.4650386	total: 49.9ms	remaining: 1.2s
# 4:	learn: 0.4292513	total: 59.8ms	remaining: 1.14s
# 5:	learn: 0.3989429	total: 65.7ms	remaining: 1.03s
# 6:	learn: 0.3731130	total: 78.2ms	remaining: 1.04s
# 7:	learn: 0.3510099	total: 88.3ms	remaining: 1.01s
# 8:	learn: 0.3318490	total: 101ms	remaining: 1.02s
# 9:	learn: 0.3153129	total: 107ms	remaining: 960ms
# 10:	learn: 0.3011227	total: 113ms	remaining: 911ms
# 11:	learn: 0.2890321	total: 120ms	remaining: 879ms
# 12:	learn: 0.2782429	total: 132ms	remaining: 886ms
# 13:	learn: 0.2684901	total: 146ms	remaining: 894ms
# 14:	learn: 0.2594807	total: 158ms	remaining: 897ms
# 15:	learn: 0.2517997	total: 171ms	remaining: 898ms
# 16:	learn: 0.2450169	total: 184ms	remaining: 896ms
# 17:	learn: 0.2389453	total: 196ms	remaining: 893ms
# ...

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print()
from sklearn.metrics import accuracy_score
print("Accuracy : ",accuracy_score(y_test,y_pred)*100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.14      0.22       584
#            1       0.95      0.99      0.97      9247
#
#     accuracy                           0.94      9831
#    macro avg       0.77      0.57      0.60      9831
# weighted avg       0.93      0.94      0.93      9831
#
#
# Accuracy :  94.29356118400976
